# %%
# %pylab inline
import sys,os
sys.path.append("..")
import tempfile
import shutil
import trappy
trace_sched = "/home/leoy/Documents/Work_disk/tools/tunning/trace_sched_cpu_load_8_threads.dat"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
run1 = trappy.Run(trace_sched)

# %%
run1.sched_load_avg_cpu.data_frame
# Out:
#                __comm  __cpu  __pid  cpu  load_avg  load_sum  \
# Time
# 0.000004       rt-app      3    833    3         0     42124
# 0.000006       rt-app      3    833    3         0     52057
# 0.000021  migration/3      3     23    3         0     52057
# 0.000023  migration/3      3     23    3         0     58385
# 0.000028  migration/3      3     23    0         0      4485
# 0.000047  migration/3      3     23    2         7    541667
# 0.000049  migration/3      3     23    2         7    657203
# 0.000059  migration/3      3     23    3         0     58385
# 0.000062  migration/3      3     23    3         0     58385
# 0.000146       <idle>      0      0    0         0      4485
# 0.000155       <idle>      0      0    0         0      4485
# 0.000243    trace-cmd      2    829    2         7    657203
# 0.000246    trace-cmd      2    829    2        14    681992
# 0.000275       <idle>      2      0    2        14    681992
# 0.000279       <idle>      2      0    2        14    681992
# 0.000302    trace-cmd      2    827    2        14    681992
# 0.000304    trace-cmd      2    827    2        14    688533
# 0.000319       <idle>      1      0    1         0         0
# 0.000326       <idle>      1      0    1         0         0
# 0.000351       <idle>      2      0    2        14    688533
# 0.000355       <idle>      2      0    2        14    688533
# 0.000363    trace-cmd      1    825    1         0         0
# 0.000366    trace-cmd      1    825    1         0      7068
# 0.000376    trace-cmd      2    826    2        14    688533
# 0.000379    trace-cmd      2    826    2        14    695918
# 0.000401       <idle>      1      0    1         0      7068
# 0.000404       <idle>      1      0    1         0      7068
# 0.000412    trace-cmd      1    826    1         0      7068
# 0.000414    trace-cmd      1    826    1         0      8244
# 0.000607    trace-cmd      3    830    3         0     58385
# ...               ...    ...    ...  ...       ...       ...
# 5.266355       <idle>      1      0    1         0     16607
# 5.266372       <idle>      7      0    7         0       683
# 5.266376       <idle>      7      0    7         0       683
# 5.266483    trace-cmd      1    825    1         0     16607
# 5.266487    trace-cmd      1    825    1         0    161507
# 5.266572      thread0      7    840    7         0       683
# 5.266576      thread0      7    840    7         0     21704
# 5.266587       <idle>      4      0    4         0     24599
# 5.266592       <idle>      4      0    4         0     24599
# 5.266616      thread0      7    840    7         0     55030
# 5.266679      thread0      4    839    4         0     24599
# 5.266681      thread0      4    839    4         0     45218
# 5.266698      thread0      4    839    4         0     56482
# 5.266783       <idle>      5      0    5         5    250831
# 5.266788       <idle>      5      0    5         5    250831
# 5.266875      thread0      5    841    5         5    250831
# 5.266877      thread0      5    841    5         5    286601
# 5.266893      thread0      5    841    5         5    297865
# 5.266976       <idle>      6      0    6         3    169617
# 5.266981       <idle>      6      0    6         3    169617
# 5.267063      thread0      6    834    6         3    169617
# 5.267065      thread0      6    834    6         3    223137
# 5.267081      thread0      6    834    6         3    234401
# 5.267280       <idle>      4      0    4         0         0
# 5.267293       <idle>      4      0    4         0         0
# 5.268240       rt-app      4    833    4         0         0
# 5.268246       rt-app      4    833    4         7    336468
# 5.268295       rt-app      4    833    4         7    377428
# 5.268516       <idle>      5      0    5         4    198044
# 5.268530       <idle>      5      0    5         4    198044
#
#           runnable_load_avg  util_avg  util_sum
# Time
# 0.000004                  0        25      1189
# 0.000006                  0        25      1490
# 0.000021                  0        25      1490
# 0.000023                  0        25      1490
# 0.000028                  0         0         0
# 0.000047                  7        44      2590
# 0.000049                  7        44      2922
# 0.000059                  1        25      1490
# 0.000062                  1        25      1490
# 0.000146                  0         0         0
# 0.000155                  0         0         0
# 0.000243                  7        44      2922
# 0.000246                 14        65      3043
# 0.000275                 14        65      3053
# 0.000279                 14        65      3053
# 0.000302                 14        65      3053
# 0.000304                 14        65      3084
# 0.000319                  0         0         0
# 0.000326                  0         0         0
# 0.000351                 14        65      3090
# 0.000355                 14        65      3090
# 0.000363                  0         0         0
# 0.000366                  0         0       186
# 0.000376                 14        65      3090
# 0.000379                 14        65      3125
# 0.000401                  0         0       195
# 0.000404                  0         0       195
# 0.000412                  0         0       195
# 0.000414                  0         0       209
# 0.000607                  1        25      1490
# ...                     ...       ...       ...
# 5.266355                  0        17       816
# 5.266372                  0         3       177
# 5.266376                  0         3       177
# 5.266483                  0        17       816
# 5.266487                  0        17      1276
# 5.266572                  0         3       177
# 5.266576                  0         3       408
# 5.266587                  0         7       339
# 5.266592                  0         7       339
# 5.266616                  8         8       445
# 5.266679                  0         7       339
# 5.266681                  0         7       576
# 5.266698                  3         7       594
# 5.266783                  5        13       632
# 5.266788                  5        13       632
# 5.266875                  5        13       632
# 5.266877                  5        13       877
# 5.266893                  2        13       895
# 5.266976                  3        10       481
# 5.266981                  3        10       481
# 5.267063                  3        10       481
# 5.267065                  3        10       721
# 5.267081                  7        10       739
# 5.267280                  0         4       455
# 5.267293                  0         4       455
# 5.268240                  0         4       455
# 5.268246                  7        34      1589
# 5.268295                 27        34      1649
# 5.268516                  5        18       875
# 5.268530                  5        18       875
#
# [4843 rows x 9 columns]

# %%
    l = trappy.ILinePlot(
            run1,                                            # TRAPpy run Object
            run1.sched_load_avg_cpu,                         # TRAPpy Event (maps to a unique word in the Trace)
            column=[                                         # Column(s)
                "load_avg",
                "util_avg",
                "runnable_load_avg"],
            
            filters={                                        # Filter the data  
                "cpu": [
                    2]},
        
            pivot="cpu",                                     # One plot for each pivot will be created
        
            per_line=1,                                      # Number of graphs per line
            drawstyle="steps-post")
    l.view()
# Out:
# <table style="width: 900px; border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_1180680d0c48434dac7088898a61fd44" style="width: 900px; height: 400px;">
#             <script>
#             var ilp_req = require.config( {
#
#                 paths: {
#                     "dygraph-sync": '/nbextensions/plotter_scripts/ILinePlot/synchronizer',
#                     "dygraph": '/nbextensions/plotter_scripts/ILinePlot/dygraph-combined',
#                     "ILinePlot": '/nbextensions/plotter_scripts/ILinePlot/ILinePlot',
#                     "underscore": '/nbextensions/plotter_scripts/ILinePlot/underscore-min',
#                 },
#
#                 shim: {
#                     "dygraph-sync": ["dygraph"],
#                     "ILinePlot": {
#
#                         "deps": ["dygraph-sync", "dygraph", "underscore"],
#                         "exports":  "ILinePlot"
#                     }
#                 }
#             });
#                 ilp_req(["require", "ILinePlot"], function() {
#                 ILinePlot.generate('fig_1180680d0c48434dac7088898a61fd44', '/nbextensions/');
#             });
#             </script>
#         </div></td>
# </tr>
# <tr>
# <td style="border-style: hidden;"><div style="text-align:right; width: 900px; height: auto;"; id="fig_1180680d0c48434dac7088898a61fd44_legend"></div></td>
# </tr>
# </table>

# %%
    l = trappy.ILinePlot(
            run1,                                            # TRAPpy run Object
            run1.sched_load_avg_cpu,                         # TRAPpy Event (maps to a unique word in the Trace)
            column=[                                         # Column(s)
                "util_avg"],
            
            filters={                                        # Filter the data  
                "cpu": [
                    2]},
        
            pivot="cpu",                                     # One plot for each pivot will be created
        
            per_line=1,                                      # Number of graphs per line
            drawstyle="steps-post")
    l.view()
# Out:
# <table style="width: 900px; border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_e18534b0c6ad44cb8f27eda9ec745f7b" style="width: 900px; height: 400px;">
#             <script>
#             var ilp_req = require.config( {
#
#                 paths: {
#                     "dygraph-sync": '/nbextensions/plotter_scripts/ILinePlot/synchronizer',
#                     "dygraph": '/nbextensions/plotter_scripts/ILinePlot/dygraph-combined',
#                     "ILinePlot": '/nbextensions/plotter_scripts/ILinePlot/ILinePlot',
#                     "underscore": '/nbextensions/plotter_scripts/ILinePlot/underscore-min',
#                 },
#
#                 shim: {
#                     "dygraph-sync": ["dygraph"],
#                     "ILinePlot": {
#
#                         "deps": ["dygraph-sync", "dygraph", "underscore"],
#                         "exports":  "ILinePlot"
#                     }
#                 }
#             });
#                 ilp_req(["require", "ILinePlot"], function() {
#                 ILinePlot.generate('fig_e18534b0c6ad44cb8f27eda9ec745f7b', '/nbextensions/');
#             });
#             </script>
#         </div></td>
# </tr>
# <tr>
# <td style="border-style: hidden;"><div style="text-align:right; width: 900px; height: auto;"; id="fig_e18534b0c6ad44cb8f27eda9ec745f7b_legend"></div></td>
# </tr>
# </table>

# %%
    l = trappy.ILinePlot(
            run1,                                            # TRAPpy run Object
            run1.sched_load_avg_cpu,                         # TRAPpy Event (maps to a unique word in the Trace)
            column=[                                         # Column(s)
                "runnable_load_avg"],
            
            filters={                                        # Filter the data  
                "cpu": [
                    2]},
        
            pivot="cpu",                                     # One plot for each pivot will be created
        
            per_line=1,                                      # Number of graphs per line
            drawstyle="steps-post")
    l.view()
# Out:
# <table style="width: 900px; border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_73d09e4b99b947a998d21c3892331722" style="width: 900px; height: 400px;">
#             <script>
#             var ilp_req = require.config( {
#
#                 paths: {
#                     "dygraph-sync": '/nbextensions/plotter_scripts/ILinePlot/synchronizer',
#                     "dygraph": '/nbextensions/plotter_scripts/ILinePlot/dygraph-combined',
#                     "ILinePlot": '/nbextensions/plotter_scripts/ILinePlot/ILinePlot',
#                     "underscore": '/nbextensions/plotter_scripts/ILinePlot/underscore-min',
#                 },
#
#                 shim: {
#                     "dygraph-sync": ["dygraph"],
#                     "ILinePlot": {
#
#                         "deps": ["dygraph-sync", "dygraph", "underscore"],
#                         "exports":  "ILinePlot"
#                     }
#                 }
#             });
#                 ilp_req(["require", "ILinePlot"], function() {
#                 ILinePlot.generate('fig_73d09e4b99b947a998d21c3892331722', '/nbextensions/');
#             });
#             </script>
#         </div></td>
# </tr>
# <tr>
# <td style="border-style: hidden;"><div style="text-align:right; width: 900px; height: auto;"; id="fig_73d09e4b99b947a998d21c3892331722_legend"></div></td>
# </tr>
# </table>

# %%
    l = trappy.ILinePlot(
            run1,                                            # TRAPpy run Object
            run1.sched_load_avg_cpu,                         # TRAPpy Event (maps to a unique word in the Trace)
            column=[                                         # Column(s)
                "load_avg"],
            
            filters={                                        # Filter the data  
                "cpu": [
                    2]},
        
            pivot="cpu",                                     # One plot for each pivot will be created
        
            per_line=1,                                      # Number of graphs per line
            drawstyle="steps-post")
    l.view()
# Out:
# <table style="width: 900px; border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_4e2ea3145dbe4509bd64b2028cf2159d" style="width: 900px; height: 400px;">
#             <script>
#             var ilp_req = require.config( {
#
#                 paths: {
#                     "dygraph-sync": '/nbextensions/plotter_scripts/ILinePlot/synchronizer',
#                     "dygraph": '/nbextensions/plotter_scripts/ILinePlot/dygraph-combined',
#                     "ILinePlot": '/nbextensions/plotter_scripts/ILinePlot/ILinePlot',
#                     "underscore": '/nbextensions/plotter_scripts/ILinePlot/underscore-min',
#                 },
#
#                 shim: {
#                     "dygraph-sync": ["dygraph"],
#                     "ILinePlot": {
#
#                         "deps": ["dygraph-sync", "dygraph", "underscore"],
#                         "exports":  "ILinePlot"
#                     }
#                 }
#             });
#                 ilp_req(["require", "ILinePlot"], function() {
#                 ILinePlot.generate('fig_4e2ea3145dbe4509bd64b2028cf2159d', '/nbextensions/');
#             });
#             </script>
#         </div></td>
# </tr>
# <tr>
# <td style="border-style: hidden;"><div style="text-align:right; width: 900px; height: auto;"; id="fig_4e2ea3145dbe4509bd64b2028cf2159d_legend"></div></td>
# </tr>
# </table>
