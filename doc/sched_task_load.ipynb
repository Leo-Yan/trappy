# %%
# %pylab inline
import sys,os
sys.path.append("..")
import tempfile
import shutil
import trappy
trace_sched = "/home/leoy/Documents/Work_disk/tools/tunning/trace_sched_task_load_8_threads.dat"
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
run1 = trappy.Run(trace_sched)

# %%
run = trappy.Run("/home/leoy/Downloads/trace.dat")
run.sched_switch.data_frame
# Out:
#                 __comm  __cpu  __pid    next_comm  next_pid  next_prio  \
# Time
# 0.000009        rt-app      5    849  migration/5        33          0
# 0.000054   migration/5      5     33    swapper/5         0        120
# 0.000073     trace-cmd      4    846    swapper/4         0        120
# 0.000098        <idle>      4      0    trace-cmd       845        120
# 0.000118     trace-cmd      4    845    swapper/4         0        120
# 0.000194        <idle>      6      0    trace-cmd       849        120
# 0.000288     trace-cmd      0    848    swapper/0         0        120
# 0.000320        <idle>      0      0    trace-cmd       841        120
# 0.000346     trace-cmd      0    841    swapper/0         0        120
# 0.000358     trace-cmd      7    847    swapper/7         0        120
# 0.000382        <idle>      7      0    trace-cmd       848        120
# 0.000403     trace-cmd      7    848    swapper/7         0        120
# ...

# %%
run1.sched_load_avg_task.data_frame
# Out:
#                __comm  __cpu  __pid         comm  load_avg  load_sum  \
# Time
# 0.000000       rt-app      3    838    trace-cmd       976  46625838
# 0.000019       rt-app      3    838    trace-cmd      1007  48085924
# 0.000038  migration/3      3     23    trace-cmd      1007  48149412
# 0.000159       <idle>      1      0    trace-cmd       976  46625838
# 0.000192    trace-cmd      1    833    trace-cmd       976  46819374
# 0.000386       <idle>      5      0    trace-cmd      1007  48149412
# 0.000505       <idle>      4      0    trace-cmd       968  46233549
# 0.000533       <idle>      4      0    trace-cmd       968  46233549
# 0.000571    trace-cmd      4    831    trace-cmd       968  46301133
# 0.000583       <idle>      6      0    trace-cmd       991  47356159
# 0.000625    trace-cmd      6    835    trace-cmd       991  47553791
# 0.000633       <idle>      4      0    trace-cmd      1006  48072612
# ...

# %%
    l = trappy.ILinePlot(
            run1,                                            # TRAPpy run Object
            run1.sched_load_avg_task,                        # TRAPpy Event (maps to a unique word in the Trace)
            column=[                                         # Column(s)
                "load_avg",
                "util_avg"],
            
            filters={                                        # Filter the data  
                "pid": [
                    844]},
            pivot="pid",                                     # One plot for each pivot will be created
        
            per_line=1,                                      # Number of graphs per line
            drawstyle="steps-post")
    l.view()
# Out:
# <table style="width: 900px; border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_b8c5ea64430248549d4965959ee2a4e7" style="width: 900px; height: 400px;">
#             <script>
#             var ilp_req = require.config( {
#
#                 paths: {
#                     "dygraph-sync": '/nbextensions/plotter_scripts/ILinePlot/synchronizer',
#                     "dygraph": '/nbextensions/plotter_scripts/ILinePlot/dygraph-combined',
#                     "ILinePlot": '/nbextensions/plotter_scripts/ILinePlot/ILinePlot',
#                     "underscore": '/nbextensions/plotter_scripts/ILinePlot/underscore-min',
#                 },
#
#                 shim: {
#                     "dygraph-sync": ["dygraph"],
#                     "ILinePlot": {
#
#                         "deps": ["dygraph-sync", "dygraph", "underscore"],
#                         "exports":  "ILinePlot"
#                     }
#                 }
#             });
# ...

# %%
    l = trappy.ILinePlot(
            run1,                                            # TRAPpy run Object
            run1.sched_load_avg_task,                        # TRAPpy Event (maps to a unique word in the Trace)
            column=[                                         # Column(s)
                "load_avg",
                "util_avg"],
            
            filters={                                        # Filter the data  
                "pid": [
                    839]},
            pivot="pid",                                     # One plot for each pivot will be created
        
            per_line=1,                                      # Number of graphs per line
            drawstyle="steps-post")
    l.view()
# Out:
# <table style="width: 900px; border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_d6c4ea083b61438091bdbbcdbd6b24aa" style="width: 900px; height: 400px;">
#             <script>
#             var ilp_req = require.config( {
#
#                 paths: {
#                     "dygraph-sync": '/nbextensions/plotter_scripts/ILinePlot/synchronizer',
#                     "dygraph": '/nbextensions/plotter_scripts/ILinePlot/dygraph-combined',
#                     "ILinePlot": '/nbextensions/plotter_scripts/ILinePlot/ILinePlot',
#                     "underscore": '/nbextensions/plotter_scripts/ILinePlot/underscore-min',
#                 },
#
#                 shim: {
#                     "dygraph-sync": ["dygraph"],
#                     "ILinePlot": {
#
#                         "deps": ["dygraph-sync", "dygraph", "underscore"],
#                         "exports":  "ILinePlot"
#                     }
#                 }
#             });
# ...

# %%
    l = trappy.ILinePlot(
            run1,                                            # TRAPpy run Object
            run1.sched_load_avg_task,                        # TRAPpy Event (maps to a unique word in the Trace)
            column=[                                         # Column(s)
                "load_sum",
                ],
            
            filters={                                        # Filter the data  
                "pid": [
                    839]},
            pivot="pid",                                     # One plot for each pivot will be created
        
            per_line=1,                                      # Number of graphs per line
            drawstyle="steps-post")
    l.view()
# Out:
# <table style="width: 900px; border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_9f4e7720400944c79f04ea2cc7cfba22" style="width: 900px; height: 400px;">
#             <script>
#             var ilp_req = require.config( {
#
#                 paths: {
#                     "dygraph-sync": '/nbextensions/plotter_scripts/ILinePlot/synchronizer',
#                     "dygraph": '/nbextensions/plotter_scripts/ILinePlot/dygraph-combined',
#                     "ILinePlot": '/nbextensions/plotter_scripts/ILinePlot/ILinePlot',
#                     "underscore": '/nbextensions/plotter_scripts/ILinePlot/underscore-min',
#                 },
#
#                 shim: {
#                     "dygraph-sync": ["dygraph"],
#                     "ILinePlot": {
#
#                         "deps": ["dygraph-sync", "dygraph", "underscore"],
#                         "exports":  "ILinePlot"
#                     }
#                 }
#             });
# ...

# %%
    l = trappy.ILinePlot(
            run1,                                            # TRAPpy run Object
            run1.sched_load_avg_task,                        # TRAPpy Event (maps to a unique word in the Trace)
            column=[                                         # Column(s)
                "util_sum",
                ],
            
            filters={                                        # Filter the data  
                "pid": [
                    839]},
            pivot="pid",                                     # One plot for each pivot will be created
        
            per_line=1,                                      # Number of graphs per line
            drawstyle="steps-post")
    l.view()
# Out:
# <table style="width: 900px; border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_2bdd8f679a744bd085f6e9bf598ff2de" style="width: 900px; height: 400px;">
#             <script>
#             var ilp_req = require.config( {
#
#                 paths: {
#                     "dygraph-sync": '/nbextensions/plotter_scripts/ILinePlot/synchronizer',
#                     "dygraph": '/nbextensions/plotter_scripts/ILinePlot/dygraph-combined',
#                     "ILinePlot": '/nbextensions/plotter_scripts/ILinePlot/ILinePlot',
#                     "underscore": '/nbextensions/plotter_scripts/ILinePlot/underscore-min',
#                 },
#
#                 shim: {
#                     "dygraph-sync": ["dygraph"],
#                     "ILinePlot": {
#
#                         "deps": ["dygraph-sync", "dygraph", "underscore"],
#                         "exports":  "ILinePlot"
#                     }
#                 }
#             });
# ...

# %%
    l = trappy.ILinePlot(
            run1,                                            # TRAPpy run Object
            run1.sched_load_avg_task,                        # TRAPpy Event (maps to a unique word in the Trace)
            column=[                                         # Column(s)
                "period_contrib",
                ],
            
            filters={                                        # Filter the data  
                "pid": [
                    839]},
            pivot="pid",                                     # One plot for each pivot will be created
        
            per_line=1,                                      # Number of graphs per line
            drawstyle="steps-post")
    l.view()
# Out:
# <table style="width: 900px; border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_44cc67d4d42f4e26893d8e9adc0e2745" style="width: 900px; height: 400px;">
#             <script>
#             var ilp_req = require.config( {
#
#                 paths: {
#                     "dygraph-sync": '/nbextensions/plotter_scripts/ILinePlot/synchronizer',
#                     "dygraph": '/nbextensions/plotter_scripts/ILinePlot/dygraph-combined',
#                     "ILinePlot": '/nbextensions/plotter_scripts/ILinePlot/ILinePlot',
#                     "underscore": '/nbextensions/plotter_scripts/ILinePlot/underscore-min',
#                 },
#
#                 shim: {
#                     "dygraph-sync": ["dygraph"],
#                     "ILinePlot": {
#
#                         "deps": ["dygraph-sync", "dygraph", "underscore"],
#                         "exports":  "ILinePlot"
#                     }
#                 }
#             });
# ...

# %%
    l = trappy.ILinePlot(
            run1,                                            # TRAPpy run Object
            run1.sched_load_avg_task,                        # TRAPpy Event (maps to a unique word in the Trace)
            column=[                                         # Column(s)
                "load_sum",
                ],
            
            filters={                                        # Filter the data  
                "pid": [
                    839]},
            pivot="pid",                                     # One plot for each pivot will be created
        
            per_line=1,                                      # Number of graphs per line
            drawstyle="steps-post")
    l.view()
# Out:
# <table style="width: 900px; border-style: hidden;">
# <tr>
# <td style="border-style: hidden;"><div class="ilineplot" id="fig_45ec01e5f1ac4a44a0116515ab08ac04" style="width: 900px; height: 400px;">
#             <script>
#             var ilp_req = require.config( {
#
#                 paths: {
#                     "dygraph-sync": '/nbextensions/plotter_scripts/ILinePlot/synchronizer',
#                     "dygraph": '/nbextensions/plotter_scripts/ILinePlot/dygraph-combined',
#                     "ILinePlot": '/nbextensions/plotter_scripts/ILinePlot/ILinePlot',
#                     "underscore": '/nbextensions/plotter_scripts/ILinePlot/underscore-min',
#                 },
#
#                 shim: {
#                     "dygraph-sync": ["dygraph"],
#                     "ILinePlot": {
#
#                         "deps": ["dygraph-sync", "dygraph", "underscore"],
#                         "exports":  "ILinePlot"
#                     }
#                 }
#             });
# ...
